# %%
import re
import pandas as pd
import pandas as pd
import re
import re
import re
import pandas as pd

text = """
run1
Average Accuracy across 1 tasks: 99.86%, Standard Deviation: 0.00%
Average Accuracy across 2 tasks: 99.66%, Standard Deviation: 0.16%
Average Accuracy across 3 tasks: 99.09%, Standard Deviation: 0.34%
Average Accuracy across 4 tasks: 98.23%, Standard Deviation: 1.27%
Average Accuracy across 5 tasks: 96.61%, Standard Deviation: 3.37%
Average Accuracy across 1 tasks: 99.95%, Standard Deviation: 0.00%
Average Accuracy across 2 tasks: 99.68%, Standard Deviation: 0.08%
Average Accuracy across 3 tasks: 99.01%, Standard Deviation: 0.26%
Average Accuracy across 4 tasks: 96.51%, Standard Deviation: 3.28%
Average Accuracy across 5 tasks: 94.19%, Standard Deviation: 6.59%
Average Accuracy across 1 tasks: 99.91%, Standard Deviation: 0.00%
Average Accuracy across 2 tasks: 99.71%, Standard Deviation: 0.11%
Average Accuracy across 3 tasks: 98.97%, Standard Deviation: 0.39%
Average Accuracy across 4 tasks: 96.44%, Standard Deviation: 2.90%
Average Accuracy across 5 tasks: 88.74%, Standard Deviation: 11.00%
Average Accuracy across 1 tasks: 99.95%, Standard Deviation: 0.00%
Average Accuracy across 2 tasks: 98.57%, Standard Deviation: 1.08%
Average Accuracy across 3 tasks: 92.69%, Standard Deviation: 8.74%
Average Accuracy across 4 tasks: 92.47%, Standard Deviation: 5.68%
Average Accuracy across 5 tasks: 89.68%, Standard Deviation: 10.88%
Average Accuracy across 1 tasks: 99.95%, Standard Deviation: 0.00%
Average Accuracy across 2 tasks: 99.64%, Standard Deviation: 0.06%
Average Accuracy across 3 tasks: 98.22%, Standard Deviation: 0.34%
Average Accuracy across 4 tasks: 97.88%, Standard Deviation: 1.08%
Average Accuracy across 5 tasks: 95.32%, Standard Deviation: 4.68%
run2
Average Accuracy across 1 tasks: 99.86%, Standard Deviation: 0.00%
Average Accuracy across 2 tasks: 99.63%, Standard Deviation: 0.13%
Average Accuracy across 3 tasks: 98.69%, Standard Deviation: 1.08%
Average Accuracy across 4 tasks: 96.44%, Standard Deviation: 4.83%
Average Accuracy across 5 tasks: 94.69%, Standard Deviation: 8.23%
Average Accuracy across 1 tasks: 99.95%, Standard Deviation: 0.00%
Average Accuracy across 2 tasks: 99.78%, Standard Deviation: 0.13%
Average Accuracy across 3 tasks: 98.96%, Standard Deviation: 0.45%
Average Accuracy across 4 tasks: 97.63%, Standard Deviation: 2.44%
Average Accuracy across 5 tasks: 97.00%, Standard Deviation: 3.65%
Average Accuracy across 1 tasks: 99.91%, Standard Deviation: 0.00%
Average Accuracy across 2 tasks: 99.63%, Standard Deviation: 0.18%
Average Accuracy across 3 tasks: 99.19%, Standard Deviation: 0.44%
Average Accuracy across 4 tasks: 97.93%, Standard Deviation: 1.70%
Average Accuracy across 5 tasks: 94.30%, Standard Deviation: 7.81%
Average Accuracy across 1 tasks: 99.95%, Standard Deviation: 0.00%
Average Accuracy across 2 tasks: 99.68%, Standard Deviation: 0.08%
Average Accuracy across 3 tasks: 99.04%, Standard Deviation: 0.41%
Average Accuracy across 4 tasks: 96.39%, Standard Deviation: 3.11%
Average Accuracy across 5 tasks: 92.47%, Standard Deviation: 11.34%
Average Accuracy across 1 tasks: 99.95%, Standard Deviation: 0.00%
Average Accuracy across 2 tasks: 99.63%, Standard Deviation: 0.08%
Average Accuracy across 3 tasks: 98.98%, Standard Deviation: 0.15%
Average Accuracy across 4 tasks: 98.96%, Standard Deviation: 0.50%
Average Accuracy across 5 tasks: 97.41%, Standard Deviation: 2.42%
run3
Average Accuracy across 1 tasks: 99.86%, Standard Deviation: 0.00%
Average Accuracy across 2 tasks: 99.00%, Standard Deviation: 0.90%
Average Accuracy across 3 tasks: 97.93%, Standard Deviation: 1.62%
Average Accuracy across 4 tasks: 97.17%, Standard Deviation: 1.93%
Average Accuracy across 5 tasks: 96.07%, Standard Deviation: 3.08%
Average Accuracy across 1 tasks: 99.95%, Standard Deviation: 0.00%
Average Accuracy across 2 tasks: 99.23%, Standard Deviation: 0.73%
Average Accuracy across 3 tasks: 97.38%, Standard Deviation: 1.82%
Average Accuracy across 4 tasks: 96.73%, Standard Deviation: 2.82%
Average Accuracy across 5 tasks: 96.32%, Standard Deviation: 3.34%
Average Accuracy across 1 tasks: 99.91%, Standard Deviation: 0.00%
Average Accuracy across 2 tasks: 99.08%, Standard Deviation: 0.88%
Average Accuracy across 3 tasks: 98.41%, Standard Deviation: 1.20%
Average Accuracy across 4 tasks: 98.02%, Standard Deviation: 1.58%
Average Accuracy across 5 tasks: 97.29%, Standard Deviation: 1.68%
Average Accuracy across 1 tasks: 99.95%, Standard Deviation: 0.00%
Average Accuracy across 2 tasks: 99.20%, Standard Deviation: 0.75%
Average Accuracy across 3 tasks: 98.01%, Standard Deviation: 1.63%
Average Accuracy across 4 tasks: 96.22%, Standard Deviation: 3.52%
Average Accuracy across 5 tasks: 96.26%, Standard Deviation: 3.19%
Average Accuracy across 1 tasks: 99.95%, Standard Deviation: 0.00%
Average Accuracy across 2 tasks: 99.13%, Standard Deviation: 0.83%
Average Accuracy across 3 tasks: 97.95%, Standard Deviation: 1.67%
Average Accuracy across 4 tasks: 98.02%, Standard Deviation: 1.52%
Average Accuracy across 5 tasks: 97.71%, Standard Deviation: 1.54%
run4
Average Accuracy across 1 tasks: 99.91%. Standard Deviation: 0.00%
Average Accuracy across 2 tasks: 99.71%. Standard Deviation: 0.06%
Average Accuracy across 3 tasks: 99.00%. Standard Deviation: 0.04%
Average Accuracy across 4 tasks: 98.84%. Standard Deviation: 0.45%
Average Accuracy across 5 tasks: 97.18%. Standard Deviation: 1.77%
Average Accuracy across 1 tasks: 99.91%. Standard Deviation: 0.00%
Average Accuracy across 2 tasks: 99.70%. Standard Deviation: 0.15%
Average Accuracy across 3 tasks: 99.02%. Standard Deviation: 0.56%
Average Accuracy across 4 tasks: 98.43%. Standard Deviation: 0.84%
Average Accuracy across 5 tasks: 97.67%. Standard Deviation: 1.64%
Average Accuracy across 1 tasks: 99.95%. Standard Deviation: 0.00%
Average Accuracy across 2 tasks: 99.80%. Standard Deviation: 0.10%
Average Accuracy across 3 tasks: 99.20%. Standard Deviation: 0.11%
Average Accuracy across 4 tasks: 98.87%. Standard Deviation: 0.40%
Average Accuracy across 5 tasks: 98.22%. Standard Deviation: 1.25%
Average Accuracy across 1 tasks: 99.95%. Standard Deviation: 0.00%
Average Accuracy across 2 tasks: 99.70%. Standard Deviation: 0.25%
Average Accuracy across 3 tasks: 98.87%. Standard Deviation: 0.88%
Average Accuracy across 4 tasks: 98.65%. Standard Deviation: 0.84%
Average Accuracy across 5 tasks: 96.83%. Standard Deviation: 2.89%
Average Accuracy across 1 tasks: 99.91%. Standard Deviation: 0.00%
Average Accuracy across 2 tasks: 99.75%. Standard Deviation: 0.10%
Average Accuracy across 3 tasks: 99.16%. Standard Deviation: 0.16%
Average Accuracy across 4 tasks: 98.94%. Standard Deviation: 0.44%
Average Accuracy across 5 tasks: 96.20%. Standard Deviation: 4.32%
"""


# Define the regular expression pattern to extract the relevant information
pattern = r"run(\d+)\nAverage Accuracy across (\d+) tasks: (\d+\.\d+)%.*Standard Deviation: (\d+\.\d+)%"

# Initialize lists to store the parsed data
runs = []
tasks = []
accuracy = []
std_deviation = []

# Find all matches of the pattern in the text
matches = re.findall(pattern, text)

# Iterate over the matches and extract the relevant information
for match in matches:
    runs.append(match[0])
    tasks.append(match[1])
    accuracy.append(float(match[2]))
    std_deviation.append(float(match[3]))

# Create a dictionary to store the parsed data
parsed_data = {
    'Run': runs,
    'Tasks': tasks,
    'Accuracy': accuracy,
    'Std Dev': std_deviation
}

# Create a new dataframe to store the parsed data
parsed_df = pd.DataFrame(parsed_data)

# Print the parsed dataframe
print(parsed_df)
# Out:
#   Run Tasks  Accuracy  Std Dev
# 0   1     1     99.86      0.0
# 1   2     1     99.86      0.0
# 2   3     1     99.86      0.0
# 3   4     1     99.91      0.0

# %%
import pandas as pd
import numpy as np
import re
text = """
Average Accuracy across 1 tasks: 99.91%. Standard Deviation: 0.00%
Average Accuracy across 2 tasks: 93.50%. Standard Deviation: 6.35%
Average Accuracy across 3 tasks: 95.21%. Standard Deviation: 6.09%
Average Accuracy across 4 tasks: 86.37%. Standard Deviation: 11.97%
Average Accuracy across 5 tasks: 89.24%. Standard Deviation: 11.91%
Average Accuracy across 6 tasks: 83.88%. Standard Deviation: 10.92%
Average Accuracy across 7 tasks: 86.43%. Standard Deviation: 11.87%
Average Accuracy across 8 tasks: 84.15%. Standard Deviation: 13.17%
Average Accuracy across 9 tasks: 85.66%. Standard Deviation: 13.84%
Average Accuracy across 10 tasks: 84.87%. Standard Deviation: 12.79%
Average Accuracy across 1 tasks: 99.91%. Standard Deviation: 0.00%
Average Accuracy across 2 tasks: 93.68%. Standard Deviation: 6.28%
Average Accuracy across 3 tasks: 95.56%. Standard Deviation: 5.30%
Average Accuracy across 4 tasks: 86.36%. Standard Deviation: 11.08%
Average Accuracy across 5 tasks: 88.88%. Standard Deviation: 11.11%
Average Accuracy across 6 tasks: 78.29%. Standard Deviation: 9.54%
Average Accuracy across 7 tasks: 81.95%. Standard Deviation: 11.92%
Average Accuracy across 8 tasks: 83.97%. Standard Deviation: 13.15%
Average Accuracy across 9 tasks: 85.82%. Standard Deviation: 11.98%
Average Accuracy across 10 tasks: 85.07%. Standard Deviation: 12.12%
Average Accuracy across 1 tasks: 99.91%. Standard Deviation: 0.00%
Average Accuracy across 2 tasks: 93.48%. Standard Deviation: 6.43%
Average Accuracy across 3 tasks: 95.49%. Standard Deviation: 5.66%
Average Accuracy across 4 tasks: 87.25%. Standard Deviation: 12.14%
Average Accuracy across 5 tasks: 89.21%. Standard Deviation: 12.14%
Average Accuracy across 6 tasks: 84.85%. Standard Deviation: 11.55%
Average Accuracy across 7 tasks: 87.71%. Standard Deviation: 13.06%
Average Accuracy across 8 tasks: 85.34%. Standard Deviation: 13.47%
Average Accuracy across 9 tasks: 86.00%. Standard Deviation: 13.38%
Average Accuracy across 10 tasks: 85.32%. Standard Deviation: 12.15%
Average Accuracy across 1 tasks: 99.91%. Standard Deviation: 0.00%
Average Accuracy across 2 tasks: 93.40%. Standard Deviation: 6.50%
Average Accuracy across 3 tasks: 95.01%. Standard Deviation: 6.31%
Average Accuracy across 4 tasks: 85.88%. Standard Deviation: 12.93%
Average Accuracy across 5 tasks: 88.42%. Standard Deviation: 12.71%
Average Accuracy across 6 tasks: 83.01%. Standard Deviation: 12.92%
Average Accuracy across 7 tasks: 85.76%. Standard Deviation: 12.91%
Average Accuracy across 8 tasks: 84.34%. Standard Deviation: 12.96%
Average Accuracy across 9 tasks: 85.84%. Standard Deviation: 13.03%
Average Accuracy across 10 tasks: 84.99%. Standard Deviation: 12.68%
Average Accuracy across 1 tasks: 100.00%. Standard Deviation: 0.00%
Average Accuracy across 2 tasks: 93.53%. Standard Deviation: 6.38%
Average Accuracy across 3 tasks: 95.21%. Standard Deviation: 6.16%
Average Accuracy across 4 tasks: 86.38%. Standard Deviation: 13.14%
Average Accuracy across 5 tasks: 88.71%. Standard Deviation: 12.99%
Average Accuracy across 6 tasks: 83.96%. Standard Deviation: 13.88%
Average Accuracy across 7 tasks: 85.51%. Standard Deviation: 13.74%
Average Accuracy across 8 tasks: 84.13%. Standard Deviation: 13.43%
Average Accuracy across 9 tasks: 84.26%. Standard Deviation: 13.79%
Average Accuracy across 10 tasks: 84.43%. Standard Deviation: 12.14%"""

# Define the regular expression pattern to extract the relevant information
pattern = r"Average Accuracy across (\d+) tasks: (\d+\.\d+)%.*Standard Deviation: (\d+\.\d+)%"

# Initialize lists to store the parsed data
tasks = []
accuracy = []
std_deviation = []

# Find all matches of the pattern in the text
matches = re.findall(pattern, text)

# Iterate over the matches and extract the relevant information
for match in matches:
    tasks.append(int(match[0]))
    accuracy.append(float(match[1]))
    std_deviation.append(float(match[2]))

# Create a dictionary to store the parsed data
parsed_data = {
    'Tasks': tasks,
    'Accuracy': accuracy,
    'Std Dev': std_deviation,
    'Std Err': (np.array(std_deviation) / np.sqrt(np.array(tasks)))
}

# Create a new dataframe to store the parsed data
parsed_df = pd.DataFrame(parsed_data)

parsed_df.groupby('Tasks').mean()

# Generate LaTeX table
latex_table = parsed_df.groupby('Tasks').mean().to_latex(columns=['Accuracy', 'Std Err'], float_format="{:.2f}".format, bold_rows=True)

latex_table = (latex_table.replace('&', '\\pm'))
# Regular expression to match the accuracy and standard error values
pattern = r'(\d+\.\d+)\s\\pm\s(\d+\.\d+)'

# Find all matches
matches = re.findall(pattern, latex_table)

# Format the matches as required
formatted_results = [f"${acc} \\%\\pm {std} \\%$" for acc, std in matches]

# Print the formatted results
for result in formatted_results:
    print(result)
# Out:
# $99.93 \%\pm 0.00 \%$
# $93.52 \%\pm 4.52 \%$
# $95.30 \%\pm 3.41 \%$
# $86.45 \%\pm 6.13 \%$
# $88.89 \%\pm 5.44 \%$
# $82.80 \%\pm 4.80 \%$
# $85.47 \%\pm 4.80 \%$
# $84.39 \%\pm 4.68 \%$
# $85.52 \%\pm 4.40 \%$
# $84.94 \%\pm 3.91 \%$

# %%
## beta = 0.01
p_trends_1 = []
torch.manual_seed(SEED)
coreset_size = 0
for i in range(5):
    model = MFVI_NN(28*28, [100, 100], 10, num_tasks = 10, single_head=True).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    trend = run_vcl(model, pmnist_train_loaders,pmnist_test_loaders, optimizer, epoch_per_task, 
        coreset_size, beta=1e-2, device = device)
    p_trends_1.append(trend)
# Out:
# Average Accuracy across 1 tasks: 97.84%, Standard Deviation: 0.00%
# Average Accuracy across 2 tasks: 95.50%, Standard Deviation: 2.16%
# Average Accuracy across 3 tasks: 89.42%, Standard Deviation: 8.50%
# Average Accuracy across 4 tasks: 82.91%, Standard Deviation: 16.87%
# Average Accuracy across 5 tasks: 79.45%, Standard Deviation: 18.97%
# Average Accuracy across 6 tasks: 75.32%, Standard Deviation: 22.79%
# Average Accuracy across 7 tasks: 70.47%, Standard Deviation: 22.40%
# Average Accuracy across 8 tasks: 63.10%, Standard Deviation: 24.65%
# Average Accuracy across 9 tasks: 60.58%, Standard Deviation: 25.56%
# Average Accuracy across 10 tasks: 60.60%, Standard Deviation: 23.85%
# Average Accuracy across 1 tasks: 97.84%, Standard Deviation: 0.00%
# Average Accuracy across 2 tasks: 95.47%, Standard Deviation: 2.22%
# Average Accuracy across 3 tasks: 90.20%, Standard Deviation: 7.60%
# Average Accuracy across 4 tasks: 80.44%, Standard Deviation: 18.16%
# ...

# %%
formatted_results
# Out:
# []

# %%
parsed_df.groupby('Tasks').mean()
parsed_df
parsed_df
# Out:
#     Tasks  Accuracy  Std Dev   Std Err
# 0       1     99.86     0.00  0.000000
# 1       2     99.66     0.16  0.113137
# 2       3     99.09     0.34  0.196299
# 3       4     98.23     1.27  0.635000
# 4       5     96.61     3.37  1.507110
# 5       1     99.95     0.00  0.000000
# 6       2     99.68     0.08  0.056569
# 7       3     99.01     0.26  0.150111
# 8       4     96.51     3.28  1.640000
# 9       5     94.19     6.59  2.947138
# 10      1     99.91     0.00  0.000000
# 11      2     99.71     0.11  0.077782
# 12      3     98.97     0.39  0.225167
# 13      4     96.44     2.90  1.450000
# 14      5     88.74    11.00  4.919350
# 15      1     99.95     0.00  0.000000
# 16      2     98.57     1.08  0.763675
# 17      3     92.69     8.74  5.046041
# 18      4     92.47     5.68  2.840000
# 19      5     89.68    10.88  4.865684
# 20      1     99.95     0.00  0.000000
# 21      2     99.64     0.06  0.042426
# 22      3     98.22     0.34  0.196299
# ...

# %%
(np.array(std_deviation) / np.sqrt(np.array(tasks)))
# Out:
# array([0.        , 0.11313708, 0.19629909, 0.635     , 1.50710982,
#        0.        , 0.05656854, 0.15011107, 1.64      , 2.94713759,
#        0.        , 0.07778175, 0.2251666 , 1.45      , 4.91934955,
#        0.        , 0.76367532, 5.04604135, 2.84      , 4.86568392,
#        0.        , 0.04242641, 0.19629909, 0.54      , 2.09295963])

# %%
std_deviation
# Out:
# [0.0,
#  0.16,
#  0.34,
#  1.27,
#  3.37,
#  0.0,
#  0.08,
#  0.26,
#  3.28,
#  6.59,
#  0.0,
#  0.11,
#  0.39,
#  2.9,
#  11.0,
#  0.0,
#  1.08,
#  8.74,
#  5.68,
#  10.88,
#  0.0,
#  0.06,
#  0.34,
#  1.08,
#  4.68]

# %%
# !pip install altair==4.2.0
